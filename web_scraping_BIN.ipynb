# %%
# Check whether 'beautifulsoup4' library is installed or not
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: soupsieve
# Required-by: gdown, google, nbconvert, yfinance

# %%
# Import packages
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
# Import data
df = pd.read_excel("/content/drive/MyDrive/Web Scraping/BIN.xlsx")
df.head()
# Out:
#       bin
# 0  527351
# 1  540012
# 2  411911
# 3  535456
# 4  421808

# %%
# Create get_bin() to crawl data from web
def get_bin(bin):
  search_url = f"https://bincheck.io/details/{bin}"
  response = requests.get(search_url)
  soup = BeautifulSoup(response.text, 'lxml')
  tables = soup.find_all('table', class_='w-full table-auto')   # Find tables
  data_dict = {}

  for table in tables:
      rows = table.find_all('tr')   # Find rows in table
      for row in rows:
          cells = row.find_all('td')    # Find cells in row
          if len(cells) > 1:  # Check if the row has at least 2 cells
              key = cells[0].text.strip()
              value = cells[1].text.strip()
              data_dict[key] = value  # Add key-value pair to the dictionary

  return data_dict  # Return the dictionary containing the data

# %%
# Add new col using get_bin()
df['bin_data'] = df['bin'].apply(get_bin)

# Show data
print(df.head())
# Out:
#       bin                                           bin_data
# 0  527351  {'BIN/IIN': '527351', 'Card Brand': 'MASTERCAR...
# 1  540012  {'BIN/IIN': '540012', 'Card Brand': 'MASTERCAR...
# 2  411911  {'BIN/IIN': '411911', 'Card Brand': 'VISA', 'C...
# 3  535456  {'BIN/IIN': '535456', 'Card Brand': 'MASTERCAR...
# 4  421808  {'BIN/IIN': '421808', 'Card Brand': 'VISA', 'C...

# %%
# Convert column 'bin_data' to new dataframe with keys = column headers and values = rows
bin_table = pd.json_normalize(df['bin_data'])

# %%
# Show data
bin_table.head(10)
# Out:
#   BIN/IIN  Card Brand Card Type               Card Level  \
# 0  527351  MASTERCARD     DEBIT  PREPAID PLATINUM TRAVEL
# 1  540012  MASTERCARD    CREDIT                 TITANIUM
# 2  411911        VISA    CREDIT                SIGNATURE
# 3  535456  MASTERCARD     DEBIT                    WORLD
# 4  421808        VISA     DEBIT                 PLATINUM
# 5  552253  MASTERCARD    CREDIT                    WORLD
# 6  542550  MASTERCARD    CREDIT                    WORLD
# 7  414746        VISA    CREDIT                SIGNATURE
# 8  426588        VISA    CREDIT                 PLATINUM
# 9  409636        VISA     DEBIT        BUSINESS ENHANCED
#
#                           Issuer Name / Bank Issuer's / Bank's Website  \
# 0                GPAY NETWORK (S) PTE., LTD.                    ------
# 1  OVERSEA-CHINESE BANKING CORPORATION, LTD.                    ------
# 2                             DBS BANK, LTD.                    ------
# 3                              REVOLUT, LTD.                    ------
# 4   OVERSEA-CHINESE BANKING CORPORATION LTD.                    ------
# 5                 UNITED OVERSEAS BANK, LTD.                    ------
# 6                   CITIBANK SINGAPORE, LTD.                    ------
# 7                    CITIBANK SINGAPORE LTD.                    ------
# 8                 UNITED OVERSEAS BANK, LTD.                    ------
# 9                             DBS BANK, LTD.                    ------
#
#   Issuer / Bank Phone ISO Country Name Country Flag ISO Country Code A2  \
# 0         +6566103888        SINGAPORE                               SG
# 1              ------        SINGAPORE                               SG
# 2      +6518001111111        SINGAPORE                               SG
# 3              ------          IRELAND                               IE
# 4              ------        SINGAPORE                               SG
# 5              ------        SINGAPORE                               SG
# 6              ------        SINGAPORE                               SG
# 7              ------        SINGAPORE                               SG
# 8              ------        SINGAPORE                               SG
# 9      +6518001111111        SINGAPORE                               SG
#
#   ISO Country Code A3 ISO Country Currency
# 0                 SGP                  SGD
# 1                 SGP                  SGD
# 2                 SGP                  SGD
# 3                 IRL                  EUR
# 4                 SGP                  SGD
# 5                 SGP                  SGD
# 6                 SGP                  SGD
# 7                 SGP                  SGD
# 8                 SGP                  SGD
# 9                 SGP                  SGD

# %%
# Remove unnecessary columns
bin_table.drop(columns={"Issuer's / Bank's Website",
                        "Issuer / Bank Phone",
                        "Country Flag",
                        "ISO Country Code A2",
                        "ISO Country Code A3"},
               axis=1, inplace=True)

# %%
# Rename columns
bin_table.rename(columns={"Issuer Name / Bank": "Bank",
                          "ISO Country Name": "Country",
                          "ISO Country Currency": "Currency"},
                 inplace=True)

# %%
# Add col 'Local/ Foreign'
bin_table['Local/ Foreign'] = np.where(bin_table['Country'] == 'SINGAPORE', 'Local', 'Foreign')

# Another way to create new col
# bin_table['Location'] = bin_table['Country'].apply(lambda x: 'Local' if x == 'SINGAPORE' else 'Foreign')

# %%
bin_table.head()
# Out:
#   BIN/IIN  Card Brand Card Type               Card Level  \
# 0  527351  MASTERCARD     DEBIT  PREPAID PLATINUM TRAVEL
# 1  540012  MASTERCARD    CREDIT                 TITANIUM
# 2  411911        VISA    CREDIT                SIGNATURE
# 3  535456  MASTERCARD     DEBIT                    WORLD
# 4  421808        VISA     DEBIT                 PLATINUM
#
#                                         Bank    Country Currency  \
# 0                GPAY NETWORK (S) PTE., LTD.  SINGAPORE      SGD
# 1  OVERSEA-CHINESE BANKING CORPORATION, LTD.  SINGAPORE      SGD
# 2                             DBS BANK, LTD.  SINGAPORE      SGD
# 3                              REVOLUT, LTD.    IRELAND      EUR
# 4   OVERSEA-CHINESE BANKING CORPORATION LTD.  SINGAPORE      SGD
#
#   Local/ Foreign
# 0          Local
# 1          Local
# 2          Local
# 3        Foreign
# 4          Local

# %%
# Lưu lại dữ liệu vào file Excel
bin_table.to_excel('Bin_Data.xlsx', index=False)
